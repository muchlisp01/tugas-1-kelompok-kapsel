# %%
# !mkdir data
# !mkdir NLP_Models/slangword
# !mkdir NLP_Models/stopword_noise
# !mkdir NLP_Models/stopword_en
# !mkdir NLP_Models/stopword
# !wget -P NLP_Models/ https://raw.githubusercontent.com/muchlisp01/NLP/main/openewfile.py
# !wget -P NLP_Models/ https://raw.githubusercontent.com/muchlisp01/NLP/main/Text_Mining.py
# !wget -P NLP_Models/slangword/ https://raw.githubusercontent.com/muchlisp01/NLP/main/slangword.txt
# !wget -P NLP_Models/stopword_noise/ https://raw.githubusercontent.com/muchlisp01/NLP/main/stopword_noise.txt
# !wget -P NLP_Models/stopword_en/ https://raw.githubusercontent.com/muchlisp01/NLP/main/stopwords_en.txt
# !wget -P NLP_Models/stopword/ https://raw.githubusercontent.com/muchlisp01/NLP/main/stopword_id.txt
# !wget -P data/ https://raw.githubusercontent.com/muchlisp01/tugas-1-kelompok-kapsel/main/data/data_gigihadid.json
# !wget -P data/ https://raw.githubusercontent.com/muchlisp01/tugas-1-kelompok-kapsel/main/data/data_yolanda.json
# !wget -P data/ https://raw.githubusercontent.com/muchlisp01/tugas-1-kelompok-kapsel/main/data/data_zayn.json
# Out:
# mkdir: cannot create directory ‘NLP_Models/slangword’: No such file or directory
# mkdir: cannot create directory ‘NLP_Models/stopword_noise’: No such file or directory
# mkdir: cannot create directory ‘NLP_Models/stopword_en’: No such file or directory
# mkdir: cannot create directory ‘NLP_Models/stopword’: No such file or directory
# --2021-11-01 19:18:46--  https://raw.githubusercontent.com/muchlisp01/NLP/main/openewfile.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 230 [text/plain]
# Saving to: ‘NLP_Models/openewfile.py’
#
# openewfile.py       100%[===================>]     230  --.-KB/s    in 0s
#
# 2021-11-01 19:18:46 (4.98 MB/s) - ‘NLP_Models/openewfile.py’ saved [230/230]
#
# --2021-11-01 19:18:46--  https://raw.githubusercontent.com/muchlisp01/NLP/main/Text_Mining.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10089 (9.9K) [text/plain]
# Saving to: ‘NLP_Models/Text_Mining.py’
#
# Text_Mining.py      100%[===================>]   9.85K  --.-KB/s    in 0.001s
#
# 2021-11-01 19:18:46 (16.2 MB/s) - ‘NLP_Models/Text_Mining.py’ saved [10089/10089]
#
# --2021-11-01 19:18:46--  https://raw.githubusercontent.com/muchlisp01/NLP/main/slangword.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36968 (36K) [text/plain]
# Saving to: ‘NLP_Models/slangword/slangword.txt’
#
# slangword.txt       100%[===================>]  36.10K  --.-KB/s    in 0.003s
#
# 2021-11-01 19:18:46 (12.1 MB/s) - ‘NLP_Models/slangword/slangword.txt’ saved [36968/36968]
#
# --2021-11-01 19:18:46--  https://raw.githubusercontent.com/muchlisp01/NLP/main/stopword_noise.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1780 (1.7K) [text/plain]
# Saving to: ‘NLP_Models/stopword_noise/stopword_noise.txt’
#
# stopword_noise.txt  100%[===================>]   1.74K  --.-KB/s    in 0s
#
# 2021-11-01 19:18:47 (26.4 MB/s) - ‘NLP_Models/stopword_noise/stopword_noise.txt’ saved [1780/1780]
#
# --2021-11-01 19:18:47--  https://raw.githubusercontent.com/muchlisp01/NLP/main/stopwords_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15141 (15K) [text/plain]
# Saving to: ‘NLP_Models/stopword_en/stopwords_en.txt’
#
# stopwords_en.txt    100%[===================>]  14.79K  --.-KB/s    in 0s
#
# 2021-11-01 19:18:47 (62.5 MB/s) - ‘NLP_Models/stopword_en/stopwords_en.txt’ saved [15141/15141]
#
# --2021-11-01 19:18:47--  https://raw.githubusercontent.com/muchlisp01/NLP/main/stopword_id.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8401 (8.2K) [text/plain]
# Saving to: ‘NLP_Models/stopword/stopword_id.txt’
#
# stopword_id.txt     100%[===================>]   8.20K  --.-KB/s    in 0s
#
# 2021-11-01 19:18:47 (55.4 MB/s) - ‘NLP_Models/stopword/stopword_id.txt’ saved [8401/8401]
#
# --2021-11-01 19:18:47--  https://raw.githubusercontent.com/muchlisp01/tugas-1-kelompok-kapsel/main/data/data_gigihadid.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32820481 (31M) [text/plain]
# Saving to: ‘data/data_gigihadid.json’
#
# data_gigihadid.json 100%[===================>]  31.30M   152MB/s    in 0.2s
#
# 2021-11-01 19:18:48 (152 MB/s) - ‘data/data_gigihadid.json’ saved [32820481/32820481]
#
# --2021-11-01 19:18:48--  https://raw.githubusercontent.com/muchlisp01/tugas-1-kelompok-kapsel/main/data/data_yolanda.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62486461 (60M) [text/plain]
# Saving to: ‘data/data_yolanda.json’
#
# data_yolanda.json   100%[===================>]  59.59M   182MB/s    in 0.3s
#
# 2021-11-01 19:18:49 (182 MB/s) - ‘data/data_yolanda.json’ saved [62486461/62486461]
#
# --2021-11-01 19:18:49--  https://raw.githubusercontent.com/muchlisp01/tugas-1-kelompok-kapsel/main/data/data_zayn.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88172442 (84M) [text/plain]
# Saving to: ‘data/data_zayn.json’
#
# data_zayn.json      100%[===================>]  84.09M   138MB/s    in 0.6s
#
# 2021-11-01 19:18:50 (138 MB/s) - ‘data/data_zayn.json’ saved [88172442/88172442]

# %%
# !pip install unidecode twython tweepy beautifulsoup4 tika
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.2-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.2 MB/s
# Collecting twython
#   Downloading twython-3.9.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Collecting tika
#   Downloading tika-1.24.tar.gz (28 kB)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from twython) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from twython) (1.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.4.0->twython) (3.1.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->twython) (1.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tika) (57.4.0)
# Building wheels for collected packages: tika
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32891 sha256=f0946bedf37eb51437689ba03dc73389598b8720774b8bab903839818ddbc1a9
#   Stored in directory: /root/.cache/pip/wheels/ec/2b/38/58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built tika
# Installing collected packages: unidecode, twython, tika
# Successfully installed tika-1.24 twython-3.9.1 unidecode-1.3.2

# %%
import warnings; warnings.simplefilter('ignore')
import tweepy, json, nltk, urllib.request, requests
from urllib.request import Request, urlopen
from twython import TwythonStreamer
from bs4 import BeautifulSoup as bs

# %%
Ck = 'AxcBZJIgNK8dbdFMnEFj5cBGZ'
Cs = 'p2hFgXIW4mAp1mYyOVOHd5S5aZ6AUos2ewALwzPQUktNsTyaVF' 
At = '1414815395278557185-TAKI5qhUhDV7npq4r8IEnh3UVvyG9x' 
As = 'xEBA8ACaNsWAatXHdemPQTPa2usdrE7x1EJ0HIbyNtMFg' 
'Done'
# Out:
# 'Done'

# %%
def twitter_connect(Ck, Cs, At, As, verbose = 0):
    try:
        auth = tweepy.OAuthHandler(Ck, Cs)
        auth.set_access_token(At, As)
        twitter = tweepy.API(auth, timeout=120)
        if verbose != 0:
            user = twitter.verify_credentials()
            print('Welcome "%s" you are now connected to twitter server' %user.name)
        return twitter
    except:
        print("Connection failed, please check your API keys or connection")
        return None

# %%
twitter = twitter_connect(Ck, Cs, At, As, verbose = 1)
# Out:
# Welcome "Muchlis Pratama Putra" you are now connected to twitter server

# %%
# !pip install docx2txt
import json
import pandas as pd
import re, os, itertools
from tqdm import tqdm
from nltk.stem import WordNetLemmatizer
from nltk import sent_tokenize, word_tokenize
from spacy.lang.id import Indonesian
from html import unescape
from unidecode import unidecode
from nltk.tokenize import TweetTokenizer; Tokenizer = TweetTokenizer(reduce_len=True)
from nltk.stem import PorterStemmer;ps = PorterStemmer()
from string import punctuation
from textblob import TextBlob
# Out:
# Collecting docx2txt
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
# Building wheels for collected packages: docx2txt
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=b5d08cd91111b9c02e803a50e3dcd1dc9eb686dedf128e5bb376f390ce34fd73
#   Stored in directory: /root/.cache/pip/wheels/b7/20/b2/473e3aea9a0c0d3e7b2f7bd81d06d0794fec12752733d1f3a8
# Successfully built docx2txt
# Installing collected packages: docx2txt
# Successfully installed docx2txt-0.8

# %%
data1 = pd.read_json('data/data_gigihadid.json', lines=True)
data2 = pd.read_json('data/data_yolanda.json', lines=True)
data3 = pd.read_json('data/data_zayn.json', lines=True)
data=pd.concat([data1,data2,data3]).reset_index(drop=True)

# %%
len(data)
# Out:
# 32177

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
data.rename(columns={'full_text':'text'},inplace=True)

# %%
from NLP_Models import Text_Mining as tm
from NLP_Models import openewfile as of
import time
from tqdm import tqdm
#import swifter


def cleanningtext(data, both = True, onlyclean = False, sentiment = False):
    print('Cleaning Text')
    fSlang = of.openfile(path = 'NLP_Models/slangword')
    bahasa = 'en'
    stops, lemmatizer = tm.LoadStopWords(bahasa, sentiment = sentiment)
    sw=open(fSlang,encoding='utf-8', errors ='ignore', mode='r');SlangS=sw.readlines();sw.close()
    SlangS = {slang.strip().split(':')[0]:slang.strip().split(':')[1] for slang in SlangS}
  
    start_time = time.time()
    tqdm.pandas()
    
    if both:
        data['text'] = data['text'].astype('str')
        data['text'] = data['text'].str.lower()
        data = data[~data.text.str.contains('unavailable')]
        data['cleaned_text'] = data['text'].progress_apply(lambda x : tm.cleanText(x,fix=SlangS, pattern2 = True, lang = bahasa, lemma=lemmatizer, stops = stops, symbols_remove = True, numbers_remove = True, hashtag_remove=False, min_charLen = 2))
        data['cleaned_text'] = data['cleaned_text'].progress_apply(lambda x : tm.handlingnegation(x))
        #data['cleaned_text'] = data['cleaned_text'].progress_apply(lambda x : tm.handlingporn(x))
    elif onlyclean: 
        data['cleaned_text'] = data['text'].progress_apply(lambda x : tm.cleanText(x, fix=SlangS, pattern2 = True, lang = bahasa, lemma=lemmatizer, stops = stops, symbols_remove = True, numbers_remove = True, hashtag_remove=False, min_charLen = 3))
    else:
        data['cleaned_text'] = data['text'].progress_apply(lambda x : tm.handlingnegation(x))
    
    data = data[data['cleaned_text'].notna()]
    print("%s seconds" %(time.time()-start_time))
    
    return data

# %%
dataFinal = cleanningtext(data = data, both = True, onlyclean = False, sentiment = False)
# Out:
# Cleaning Text
# 100%|██████████| 32177/32177 [00:17<00:00, 1865.02it/s]
# 100%|██████████| 32177/32177 [00:00<00:00, 198262.30it/s]
# 17.627442359924316 seconds

# %%
dataFinal.head()
# Out:
#                  created_at  ...                                       cleaned_text
# 0 2021-11-01 05:11:16+00:00  ...                 retweet bella gigi hadid halloween
# 1 2021-11-01 04:56:15+00:00  ...  jadi sebenarnya zayn malik putus sama gigi had...
# 2 2021-11-01 04:18:08+00:00  ...  retweet zayn malik sama gigi hadid putus gara ...
# 3 2021-11-01 03:50:41+00:00  ...                                 retweet gigi hadid
# 4 2021-11-01 03:34:19+00:00  ...  berita pertama datang dari zayn yang dikenakan...
#
# [5 rows x 32 columns]

# %%
dataFinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32177 entries, 0 to 32176
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   created_at                 32177 non-null  datetime64[ns, UTC]
#  1   id                         32177 non-null  int64
#  2   id_str                     32177 non-null  int64
#  3   text                       32177 non-null  object
#  4   truncated                  32177 non-null  bool
#  5   display_text_range         32177 non-null  object
#  6   entities                   32177 non-null  object
#  7   extended_entities          7178 non-null   object
#  8   metadata                   32177 non-null  object
#  9   source                     32177 non-null  object
#  10  in_reply_to_status_id      5592 non-null   float64
#  11  in_reply_to_status_id_str  5592 non-null   float64
#  12  in_reply_to_user_id        5611 non-null   float64
#  13  in_reply_to_user_id_str    5611 non-null   float64
#  14  in_reply_to_screen_name    5611 non-null   object
#  15  user                       32177 non-null  object
#  16  geo                        0 non-null      float64
#  17  coordinates                0 non-null      float64
#  18  place                      187 non-null    object
#  19  contributors               0 non-null      float64
#  20  retweeted_status           20302 non-null  object
#  21  is_quote_status            32177 non-null  bool
#  22  retweet_count              32177 non-null  int64
#  23  favorite_count             32177 non-null  int64
#  24  favorited                  32177 non-null  bool
#  25  retweeted                  32177 non-null  bool
#  26  possibly_sensitive         9416 non-null   float64
#  27  lang                       32177 non-null  object
#  28  quoted_status_id           1286 non-null   float64
#  29  quoted_status_id_str       1286 non-null   float64
#  30  quoted_status              1183 non-null   object
#  31  cleaned_text               32177 non-null  object
# dtypes: bool(4), datetime64[ns, UTC](1), float64(10), int64(4), object(13)
# memory usage: 7.2+ MB

# %%
datacleaned=dataFinal[['cleaned_text']]
datacleaned.to_csv('data/dataclean.txt', index=False)

# %%
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-6.306870,106.746872,30km", 50  
qry = 'gigi hadid OR zayn OR yolanda'
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    print([tweet.created_at, tweet.text.encode('utf-8'), tweet.user.id, tweet.geo])
# Out:
# [datetime.datetime(2021, 11, 1, 11, 33, 32), b'Tumben nih blom ada twitt yang pengen belajar dari Zayn malik dan Gigi hadid', 2166776492, None]
# [datetime.datetime(2021, 11, 1, 10, 54, 54), b'@Askrlfess Jadi inget ocehan teman waktu liat ig cewe pake kaos putih + jeans biru sobek + sendal jepit. Temanku bi\xe2\x80\xa6 https://t.co/6TxaDEbM7J', 893445915872174080, None]
# [datetime.datetime(2021, 11, 1, 3, 34, 19), b'Berita pertama datang dari Zayn, yang dikenakan masa percobaan karena tudingan kekerasan yang diajukan oleh Yolanda\xe2\x80\xa6 https://t.co/0wCBunZ24I', 74664107, None]
# [datetime.datetime(2021, 11, 1, 0, 16, 27), b'Selama ini w kira Bela Hadid itu kakaknya, Gigi Hadid adeknya', 139963881, None]
# [datetime.datetime(2021, 10, 31, 22, 30, 28), b'@anggitaelfrida @vennyoktav Pasti sing dimaksud gigi hadid kan?', 79171031, None]
# [datetime.datetime(2021, 10, 31, 18, 43, 53), b'Zain Malik Putus Dari Gigi Hadid, Sepakat Mengasuh Anak Bersama\n#IkatanCintaEp491\nZayn Malik\n#WeAreWithZayn\n https://t.co/h6OvF14bBv', 1344787997124792320, None]
# [datetime.datetime(2021, 10, 31, 14, 29, 3), b'Zayn Malik dituding melakukan kekerasan pada Yolanda, ibu Gigi Hadid. Ini bukan kali pertama sang musisi dituding m\xe2\x80\xa6 https://t.co/NiNkcBBSsA', 69183155, None]
# [datetime.datetime(2021, 10, 31, 13, 12, 22), b'Lg kepikiran rumah tangga mas zayn mbak gigi', 532193692, None]
# [datetime.datetime(2021, 10, 31, 13, 0, 2), b'Dilaporkan Yolanda Hadid atas tindak pemukulan, Zayn Malik dan Gigi Hadid disebut masih bersama hanya karena buah h\xe2\x80\xa6 https://t.co/bncfk1jPny', 39933002, None]
# [datetime.datetime(2021, 10, 31, 9, 21, 21), b'Dugaan Lakukan Kekerasan pada Yolanda, Gigi Hadid dan Zayn Malik Putus - https://t.co/dXLiWhCOPs: Instagram/yolanda\xe2\x80\xa6 https://t.co/asIQv0wgkc', 1185539366136844289, None]
# [datetime.datetime(2021, 10, 31, 8, 43, 41), b'Pasangan Gigi Hadid dan Zayn Malik diduga memang menjalani toxic relationship sejak lama. Agar tidak terjebak, kena\xe2\x80\xa6 https://t.co/VFlIgzvmbs', 23343960, None]
# [datetime.datetime(2021, 10, 31, 7, 14, 3), b'@convomf ini gigi zayn kah?', 1212294923514339328, None]
# [datetime.datetime(2021, 10, 31, 6, 41, 57), b'Zayn akhirnya didakwa dengan kejahatan terhadap Gigi dan Yolanda Hadid. Zayn pun mengajukan pembelaan terhadap dakw\xe2\x80\xa6 https://t.co/Fx7MFo3bhJ', 1366400664960573441, None]
# [datetime.datetime(2021, 10, 31, 6, 26, 9), b'Ada apa sama gigi &amp; zayn?', 1093097521210023936, None]
# [datetime.datetime(2021, 10, 31, 6, 11, 37), b'@katainsap Trs yolanda juga nge post mukanya khai ( anak gigi sama zayn) padhaal zayn sama gigi dah sepakat, pengen\xe2\x80\xa6 https://t.co/uRgf27Vdam', 1336329696284299269, None]
# [datetime.datetime(2021, 10, 31, 6, 10, 11), b'@katainsap Gigi sama zayn kan putus\nDi sebabin karna yolanda bilang ke publik kalo zayn itu mukul dia. \nKarna yolan\xe2\x80\xa6 https://t.co/qSbTvSAciz', 1336329696284299269, None]
# [datetime.datetime(2021, 10, 31, 4, 12, 37), b'Kisruh hubungan asmara penyanyi Zayn Malik dengan supermodel Gigi Hadid terus memanas. Permasalahan keduanya dimula\xe2\x80\xa6 https://t.co/MKImWBbgxa', 23343960, None]
# [datetime.datetime(2021, 10, 31, 3, 7, 33), b'Zayn Malik dituding melakukan kekerasan pada Yolanda, ibu Gigi Hadid. Ini bukan kali pertama sang musisi dituding m\xe2\x80\xa6 https://t.co/MypaNymohI', 137282671, None]
# [datetime.datetime(2021, 10, 31, 0, 59, 34), b'Dunia entertainment hingga lifestyle dihebohkan dengan berbagai berita. Mulai dari mobil RFS Rachel Vennya diperiks\xe2\x80\xa6 https://t.co/XYC9lrpRsp', 137282671, None]
# [datetime.datetime(2021, 10, 30, 23, 40, 2), b'[POPULER HYPE] Ibu Celine Evangelista Buka Suara | Perjalanan Cinta Zayn Malik dan Gigi Hadid https://t.co/Yc2lypBCNS', 171833463, None]
# [datetime.datetime(2021, 10, 30, 18, 59, 17), b'Gigi Hadid &amp; Zayn Malik kenapaaa?!!!', 1137613826017320960, None]
# [datetime.datetime(2021, 10, 30, 17, 21, 1), b'Berseteru dengan Ibu Mertua, Zayn Malik dan Gigi Hadid Dikabarkan Putus! https://t.co/T4Kw1ebTQz', 1021110052210425856, None]
# [datetime.datetime(2021, 10, 30, 15, 56), b'@chainofbizzle @amaliaaefatamaa @hollywoodjepret Lagian Yolanda emng problematic dr dulu, kan dia yg pengen jd mode\xe2\x80\xa6 https://t.co/Gn8FwPooF3', 914220715796135936, None]
# [datetime.datetime(2021, 10, 30, 15, 33, 33), b'Berbuntut Panjang, Kasus Malik Dilaporkan Polisi oleh Ibunya Gigi Hadid https://t.co/DK1VQW0GqY https://t.co/c97vG83wDt', 41730943, None]
# [datetime.datetime(2021, 10, 30, 15, 29, 3), b'[VIDEO] Zayn Malik Dilaporkan Polisi oleh Ibunda Gigi Hadid https://t.co/uz7ncXwGtG #vlix', 41730943, None]
# [datetime.datetime(2021, 10, 30, 15, 19, 5), b'Kalo berita nya bener tentang Y yg mnta Khai di test DNA anaknya Zayn atau bukan,, secara ga langsung Y bikin imej Gigi jadi negatif,', 66950193, None]
# [datetime.datetime(2021, 10, 30, 15, 4, 24), b"Zayn yg karirnya bagus terjamin dah buat Gigi, masih aja di nyinyirin mertua.\n.\n.\nBismillah klo do'a ga pernah keti\xe2\x80\xa6 https://t.co/ssZrxWdSAr", 66950193, None]
# [datetime.datetime(2021, 10, 30, 14, 37, 1), b'@niazkilam1201 @sweetandnun Gigi sm zayn tuh blm nikah ?? @tweetnyavika @mawlida_ssi', 562854270, None]
# [datetime.datetime(2021, 10, 30, 14, 31, 9), b'Yolanda ngeselin bgt ya Allah, ga rela bgt Zayn sama Gigi putus\xf0\x9f\x98\xad', 1274188086260318209, None]
# [datetime.datetime(2021, 10, 30, 13, 45, 8), b'@heinnana @AREAJULID Statementnya mbak gigi gimana ya apa bener bang zayn nglakuin \xf0\x9f\x98\xb3', 93635859, None]
# [datetime.datetime(2021, 10, 30, 12, 41, 51), b'Zayn Malik harus menjalani sejumlah hukuman atas laporan aksi kekerasan yang dilakukannya terhadap Gigi dan ibunya,\xe2\x80\xa6 https://t.co/X8Nntxr1VU', 69183155, None]
# [datetime.datetime(2021, 10, 30, 12, 20, 7), b'@piwaygeskin zayn ompong skrg soalnya putus sm gigi', 1168543337055285248, None]
# [datetime.datetime(2021, 10, 30, 12, 5, 33), b'Zayn Malik dituding lakukan empat kekerasan dan harus jalani hukuman total 360 hari masa percobaan https://t.co/OOZwisil5b', 23343960, None]
# [datetime.datetime(2021, 10, 30, 12, 4, 2), b'Zayn Malik Bantah Semua Tuduhan Kekerasan terhadap Gigi Hadid dan Yolanda Hadid  https://t.co/hGyyKG67Fu', 171833463, None]
# [datetime.datetime(2021, 10, 30, 11, 51, 34), b'Akhir Pahit Kisah CLBK Zayn Malik dan Gigi Hadid: Zayn Malik harus menghadapi empat tuduhan kekerasan dari Yolanda\xe2\x80\xa6 https://t.co/o1FQSj9JXX', 2462686290, None]
# [datetime.datetime(2021, 10, 30, 11, 49, 5), b'Kamu di mana, dengan siapa\nSemalam berbuat apa\nKamu di mana, dengan siapa\nDi sini aku menunggumu dan bertanya\nYolan\xe2\x80\xa6 https://t.co/KZDFVeuQXX', 1361634622610698240, None]
# [datetime.datetime(2021, 10, 30, 11, 33, 41), b'Zayn Malik harus menjalani sejumlah hukuman atas laporan aksi kekerasan yang dilakukannya terhadap Gigi dan ibunya,\xe2\x80\xa6 https://t.co/ZsAu9Cros5', 137282671, None]
# [datetime.datetime(2021, 10, 30, 10, 50), b'Berantem dengan Ibu Gigi Hadid, Zayn Malik Dijatuhi Vonis Denda #NewsRCTIPlus @RCTIPlus\n\nhttps://t.co/bcpM8koPvG https://t.co/XLqHiJ96oF', 82837341, None]
# [datetime.datetime(2021, 10, 30, 9, 56, 10), b'@AwKaren91 Ini emg dajjal mak, sejak sebelum gigi pacaran sama zayn, emg kelakuannya toxic', 1128500350636285953, None]
# [datetime.datetime(2021, 10, 30, 9, 25, 45), b'adek gw tiba2 random datemg ke kamar gw trus nanyain \xe2\x80\x9ckak? agama gigi hadid sama zayn malik islam kan?\xe2\x80\x9d trus gw jaw\xe2\x80\xa6 https://t.co/BR6IPDdzNa', 938982786572066816, None]
# [datetime.datetime(2021, 10, 30, 9, 11, 50), b'@alitshariati Enaknya Gigi hadid', 1239142040710950912, None]
# [datetime.datetime(2021, 10, 30, 8, 58, 55), b'Mungkin zayn hampir diperkosa kali ama ibunya dia yg masuk rumah mereka berdua tanpa izin saat gigi hadid pergi', 1385161213634437126, None]
# [datetime.datetime(2021, 10, 30, 8, 51, 8), b'Gigi Hadid dan Zayn Malik memutuskan mengakhiri hubungan asmara. Rupanya, hubungan mereka disebut toxic. https://t.co/uUanO407Oo', 137282671, None]
# [datetime.datetime(2021, 10, 30, 8, 28, 37), b'Zayn Malik dikabarkan telah digugat ibu Gigi Hadid. https://t.co/7m4u4nzOQu', 22126902, None]
# [datetime.datetime(2021, 10, 30, 8, 23, 18), b'Zayn Malik Dipolisikan Dugaan Penganiayaan Ibunda Gigi Hadid https://t.co/bqv4w9qhhe', 261160000, None]
# [datetime.datetime(2021, 10, 30, 8, 9, 12), b'Gigi Hadid dan Zayn Malik memutuskan mengakhiri hubungan asmara. Rupanya, hubungan mereka disebut toxic. https://t.co/zD3XM9PjwJ', 69183155, None]
# [datetime.datetime(2021, 10, 30, 7, 21, 48), b"@AREAJULID gue pantengin terusnih update mereka dari kemarinan \xf0\x9f\x91\x80\nbaik2 deh ya mbak Gigi bang Zayn :')", 3297234925, None]
# [datetime.datetime(2021, 10, 30, 6, 37, 39), b'@pilcachu @nurkhaal @AREAJULID maap, ko zayn sm gigi pisah kan yg nyebarin identitas si yolanda??', 1129646346367979520, None]
# [datetime.datetime(2021, 10, 30, 6, 29, 45), b'Zayn sm gigi putus beneran ga siii ??? apa nanti ujung ujungnya jg balikan lagi \xf0\x9f\xa4\x94\xf0\x9f\xa4\x94', 3132585194, None]
# [datetime.datetime(2021, 10, 30, 6, 23, 17), b'@rnxellow @AREAJULID Yolanda share ke public fotonya Khai padahal Gigi sama Zayn udh privasi banget ke anaknya supa\xe2\x80\xa6 https://t.co/2Gu6p12GI9', 398541489, None]

# %% [markdown]
# # Retweet Terbanyak

# %%
retweet = data[['retweet_count','text']]
retweet.loc[retweet['retweet_count'].idxmax()]
# Out:
# retweet_count                    26352
# text             rt @zaynmalik: teehee
# Name: 25530, dtype: object

# %% [markdown]
# # Like Terbanyak

# %%
like = data[['favorite_count','text']]
like.loc[like['favorite_count'].idxmax()]
# Out:
# favorite_count                                                27830
# text              zayn malik dan gigi hadid resmi berpisah wst 😭...
# Name: 4907, dtype: object

# %% [markdown]
# # Visualisasi

# %% [markdown]
# ![visual.PNG](data:image/png;base64,...)

# %% [markdown]
# Gambar diatas menunjukkan kata-kata yang paling sering muncul pada data. Semakin besar ukuran teksnya berarti kata itu semakin sering muncul.

# %% [markdown]
# ![visual1.PNG](data:image/png;base64,...)

# %% [markdown]
# Gambar diatas menunjukkan kata-kata yang paling sering muncul secara bersamaan dalam satu kalimat pada data. Beberapa kata yang saling terhubung dengan garis menunjukkan bahwa kata-kata tersebut sering muncul dalam satu kalimat. Dari gambar diatas bisa kita simpulkan bahwa Zayn Malik dan Gigi Hadid telah resmi berpisah dikarenakan Yolanda, mertua dari Zayn Malik yang terlalu ikut campur dalam hubungan anaknya.

# %% [markdown]
# ![visual2.PNG](data:image/png;base64,...)

# %% [markdown]
# Pada awal periode pengambilan data, netizen banyak membicarakan tentang zayn, gigi, yolanda, dan hadid. Ini dapat dilihat pada gambar bahwa pada segmen ke-2, keempat kata tersebut saling bersinggungan
